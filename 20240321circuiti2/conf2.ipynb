# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
import sys

dir_path = os.path.abspath('')
sys.path.append(dir_path + '/../')

from interpolazione import Interpolazione, final_val

dir_path = os.path.abspath('')
FILE = dir_path + '/data/' + 'conf2.csv'
fr = pd.read_csv(FILE)

# %%
tg = np.array(fr['tg (ms)'])[:-1] * 10**-3
Vg = np.array(fr['Vg (Volt)'])[:-1]
tab = np.array(fr['tab (ms)']) * 10**-3
Vab = np.array(fr['Vab (Volt)'])
sigmaV = 0.04 / np.sqrt(12)
ν = 50 # Hz

# %%
plt.errorbar(tg, Vg, yerr=sigmaV, label='Vg')
plt.errorbar(tab, Vab, yerr=sigmaV, label='Vab')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.legend()
plt.show()

# %% [markdown]
# https://lushprojects.com/circuitjs/circuitjs.html
